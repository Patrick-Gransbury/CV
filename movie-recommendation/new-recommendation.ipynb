# %%
import time
import os
import pandas as pd
import numpy as np
import ast
import re
import requests
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

OMDB_API_KEY = "4ab406f9"
SAVE_FILE = "movies_with_ratings.csv"

# %%
# Load datasets
credits_df = pd.read_csv('credits.csv')
movies_df = pd.read_csv('movies.csv')

movies_df.rename(columns={"id": "movie_id"}, inplace=True)

# Merge datasets
movies = movies_df.merge(credits_df, on='movie_id', how="inner")
movies.drop(columns=['title_x'], inplace=True)  # Drop 'title_x' or 'title_y' based on your preference

# Rename the remaining title column ('title_y' to 'title')
movies.rename(columns={'title_y': 'title'}, inplace=True)

# Optionally, reset the index again
movies.reset_index(drop=True, inplace=True)
# Keep required columns
movies = movies[['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew', 'popularity', 'release_date']]

# %%
# Drop null values
movies.dropna(inplace=True)

# Convert stringified lists into Python lists
def convert_list(obj):
    return [i['name'] for i in ast.literal_eval(obj)]

def fetch_lead_actors(obj):
    return [i['name'] for i in ast.literal_eval(obj)[:3]]

def fetch_director(obj):
    return [i['name'] for i in ast.literal_eval(obj) if i['job'] == 'Director']

movies['genres'] = movies['genres'].apply(convert_list)
movies['keywords'] = movies['keywords'].apply(convert_list)
movies['cast'] = movies['cast'].apply(fetch_lead_actors)
movies['crew'] = movies['crew'].apply(fetch_director)
movies['year'] = pd.to_datetime(movies['release_date'], format='%d/%m/%Y', errors='coerce').dt.year
required_columns = ['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew', 'popularity', 'year']
def is_invalid_row(row):
    for col in required_columns:
        if isinstance(row[col], list) and not row[col]:  # Empty list check
            return True
        if row[col] in [None, '', np.nan]:  # Check for missing values
            return True
    return False
movies = movies[~movies.apply(is_invalid_row, axis=1)]
movies.reset_index(drop=True, inplace=True)

# %%
# Normalize popularity
scaler = MinMaxScaler()
movies['popularity_log'] = np.log1p(movies['popularity'])
movies['popularity_log_norm'] = scaler.fit_transform(movies[['popularity_log']])

# %%
# Remove spaces in tags
movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['cast'] = movies['cast'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['crew'] = movies['crew'].apply(lambda x: [i.replace(" ", "") for i in x])

# %%
def pre_processing(content):
    # Only keeping alphabets in the content 
    stemmed_content = re.sub('[^a-zA-Z]', ' ', content)
    # Removing spaces and converting to lowercase
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    return [word for word in stemmed_content if not word in stopwords.words('english')]

# %%
movies['tags'] = movies['overview'].apply(pre_processing).apply(lambda x: ' '.join(x)) + ' ' + \
                    movies['genres'].apply(lambda x: ' '.join(x)) + ' ' + \
                    movies['keywords'].apply(lambda x: ' '.join(x)) + ' ' + \
                    movies['cast'].apply(lambda x: ' '.join(x)) + ' ' + \
                    movies['crew'].apply(lambda x: ' '.join(x))

# %%
final_movies_df = movies[['movie_id', 'title', 'overview', 'cast', 'crew', 'popularity_log_norm', 'year','tags']]

# %%
final_movies_df['tags'] = final_movies_df['tags'].str.lower()
# Out:
# C:\Users\grans\AppData\Local\Temp\ipykernel_26436\4138064354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_movies_df['tags'] = final_movies_df['tags'].str.lower()

# %%
def fetch_omdb_ratings(movie_title):
    time.sleep(0.5)
    url = f"https://www.omdbapi.com/?t={movie_title}&apikey={OMDB_API_KEY}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        
        # Extract IMDb rating
        imdb_score = data.get("imdbRating")  # Example: "8.3"
        
        # Extract Rotten Tomatoes score (if available)
        rt_score = None
        if "Ratings" in data:
            for rating in data["Ratings"]:
                if rating["Source"] == "Rotten Tomatoes":
                    rt_score = rating["Value"].strip('%')  # Example: "87"

        return pd.Series([imdb_score, int(rt_score) if rt_score else None])  # Convert RT score to int

    except requests.exceptions.RequestException as e:
        print(f"Error fetching OMDb ratings for {movie_title}: {e}")
        return pd.Series([None, None])  # Return None if there's an error

# %% [markdown]
# # Should do the below parsing through the year for each movie too!!!
#
# Will have to do manually for the duplicates (there are only a few)

# %%
if os.path.exists(SAVE_FILE):
    movies_ratings = pd.read_csv(SAVE_FILE)
else:
    print("New file")
    movies_ratings = final_movies_df[['movie_id', 'title', 'overview', 'cast', 'crew', 'popularity_log_norm', 'year', 'tags']].copy()
    movies_ratings['imdb_score'] = None
    movies_ratings['rt_score'] = None

# Process each movie one by one
for index, row in movies_ratings.iterrows():
    if pd.notna(row["imdb_score"]):  # Skip if already fetched
        print(f"Skipping search for: {row['title']}")
        continue  

    print(f"🔍 Fetching ratings for: {row['title']}...")
   
    imdb, rt = fetch_omdb_ratings(row["title"])
    
    # Store results in DataFrame
    movies_ratings.at[index, "imdb_score"] = imdb
    movies_ratings.at[index, "rt_score"] = rt

    # Save after each successful request
    movies_ratings.to_csv(SAVE_FILE, index=False)
    
    print(f"✅ Saved: {row['title']} - IMDb: {imdb}, RT: {rt}%")

    time.sleep(1)  # Avoid hitting rate limits

print("🎉 Done! All available ratings saved.")
# Out:
# Skipping search for: Avatar
# Skipping search for: Pirates of the Caribbean: At World's End
# Skipping search for: Spectre
# Skipping search for: The Dark Knight Rises
# Skipping search for: John Carter
# Skipping search for: Spider-Man 3
# Skipping search for: Tangled
# Skipping search for: Avengers: Age of Ultron
# Skipping search for: Harry Potter and the Half-Blood Prince
# Skipping search for: Batman v Superman: Dawn of Justice
# Skipping search for: Superman Returns
# Skipping search for: Quantum of Solace
# Skipping search for: Pirates of the Caribbean: Dead Man's Chest
# Skipping search for: The Lone Ranger
# Skipping search for: Man of Steel
# Skipping search for: The Chronicles of Narnia: Prince Caspian
# Skipping search for: The Avengers
# Skipping search for: Pirates of the Caribbean: On Stranger Tides
# Skipping search for: Men in Black 3
# Skipping search for: The Hobbit: The Battle of the Five Armies
# Skipping search for: The Amazing Spider-Man
# Skipping search for: Robin Hood
# Skipping search for: The Hobbit: The Desolation of Smaug
# Skipping search for: The Golden Compass
# Skipping search for: King Kong
# Skipping search for: Titanic
# Skipping search for: Captain America: Civil War
# Skipping search for: Battleship
# Skipping search for: Jurassic World
# Skipping search for: Skyfall
# Skipping search for: Spider-Man 2
# Skipping search for: Iron Man 3
# Skipping search for: Alice in Wonderland
# Skipping search for: X-Men: The Last Stand
# Skipping search for: Monsters University
# Skipping search for: Transformers: Revenge of the Fallen
# Skipping search for: Transformers: Age of Extinction
# Skipping search for: Oz: The Great and Powerful
# Skipping search for: The Amazing Spider-Man 2
# Skipping search for: TRON: Legacy
# Skipping search for: Cars 2
# Skipping search for: Green Lantern
# Skipping search for: Toy Story 3
# Skipping search for: Terminator Salvation
# Skipping search for: Furious 7
# Skipping search for: World War Z
# Skipping search for: X-Men: Days of Future Past
IMDb: None, RT: None%
# 🔍 Fetching ratings for: Like Mike...
# Error fetching OMDb ratings for Like Mike: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Like%20Mike&apikey=4ab406f9
# ✅ Saved: Like Mike - IMDb: None, RT: None%
# 🔍 Fetching ratings for: The Naked Gun 33⅓: The Final Insult...
# Error fetching OMDb ratings for The Naked Gun 33⅓: The Final Insult: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=The%20Naked%20Gun%2033%E2%85%93:%20The%20Final%20Insult&apikey=4ab406f9
# ✅ Saved: The Naked Gun 33⅓: The Final Insult - IMDb: None, RT: None%
# 🔍 Fetching ratings for: A View to a Kill...
# Error fetching OMDb ratings for A View to a Kill: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=A%20View%20to%20a%20Kill&apikey=4ab406f9
# ✅ Saved: A View to a Kill - IMDb: None, RT: None%
# 🔍 Fetching ratings for: The Curse of the Were-Rabbit...
# Error fetching OMDb ratings for The Curse of the Were-Rabbit: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=The%20Curse%20of%20the%20Were-Rabbit&apikey=4ab406f9
# ✅ Saved: The Curse of the Were-Rabbit - IMDb: None, RT: None%
# 🔍 Fetching ratings for: P.S. I Love You...
# Error fetching OMDb ratings for P.S. I Love You: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=P.S.%20I%20Love%20You&apikey=4ab406f9
# ✅ Saved: P.S. I Love You - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Racing Stripes...
# Error fetching OMDb ratings for Racing Stripes: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Racing%20Stripes&apikey=4ab406f9
# ✅ Saved: Racing Stripes - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Atonement...
# Error fetching OMDb ratings for Atonement: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Atonement&apikey=4ab406f9
# ✅ Saved: Atonement - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Letters to Juliet...
# Error fetching OMDb ratings for Letters to Juliet: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Letters%20to%20Juliet&apikey=4ab406f9
# ✅ Saved: Letters to Juliet - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Black Rain...
# Error fetching OMDb ratings for Black Rain: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Black%20Rain&apikey=4ab406f9
# ✅ Saved: Black Rain - IMDb: None, RT: None%
# 🔍 Fetching ratings for: The Three Stooges...
# Error fetching OMDb ratings for The Three Stooges: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=The%20Three%20Stooges&apikey=4ab406f9
# ✅ Saved: The Three Stooges - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Corpse Bride...
# Error fetching OMDb ratings for Corpse Bride: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Corpse%20Bride&apikey=4ab406f9
# ✅ Saved: Corpse Bride - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Glory Road...
# Error fetching OMDb ratings for Glory Road: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Glory%20Road&apikey=4ab406f9
# ✅ Saved: Glory Road - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Sicario...
# Error fetching OMDb ratings for Sicario: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Sicario&apikey=4ab406f9
# ✅ Saved: Sicario - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Southpaw...
# Error fetching OMDb ratings for Southpaw: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Southpaw&apikey=4ab406f9
# ✅ Saved: Southpaw - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Drag Me to Hell...
# Error fetching OMDb ratings for Drag Me to Hell: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Drag%20Me%20to%20Hell&apikey=4ab406f9
# ✅ Saved: Drag Me to Hell - IMDb: None, RT: None%
# 🔍 Fetching ratings for: The Age of Adaline...
# Error fetching OMDb ratings for The Age of Adaline: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=The%20Age%20of%20Adaline&apikey=4ab406f9
# ✅ Saved: The Age of Adaline - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Secondhand Lions...
# Error fetching OMDb ratings for Secondhand Lions: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Secondhand%20Lions&apikey=4ab406f9
# ✅ Saved: Secondhand Lions - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Step Up 3D...
# Error fetching OMDb ratings for Step Up 3D: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Step%20Up%203D&apikey=4ab406f9
# ✅ Saved: Step Up 3D - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Blue Crush...
# Error fetching OMDb ratings for Blue Crush: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Blue%20Crush&apikey=4ab406f9
# ✅ Saved: Blue Crush - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Stranger Than Fiction...
# Error fetching OMDb ratings for Stranger Than Fiction: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Stranger%20Than%20Fiction&apikey=4ab406f9
# ✅ Saved: Stranger Than Fiction - IMDb: None, RT: None%
# 🔍 Fetching ratings for: 30 Days of Night...
# Error fetching OMDb ratings for 30 Days of Night: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=30%20Days%20of%20Night&apikey=4ab406f9
# ✅ Saved: 30 Days of Night - IMDb: None, RT: None%
# 🔍 Fetching ratings for: The Cabin in the Woods...
# Error fetching OMDb ratings for The Cabin in the Woods: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=The%20Cabin%20in%20the%20Woods&apikey=4ab406f9
# ✅ Saved: The Cabin in the Woods - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Meet the Spartans...
# Error fetching OMDb ratings for Meet the Spartans: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Meet%20the%20Spartans&apikey=4ab406f9
# ✅ Saved: Meet the Spartans - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Midnight Run...
# Error fetching OMDb ratings for Midnight Run: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Midnight%20Run&apikey=4ab406f9
# ✅ Saved: Midnight Run - IMDb: None, RT: None%
# 🔍 Fetching ratings for: The Running Man...
# Error fetching OMDb ratings for The Running Man: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=The%20Running%20Man&apikey=4ab406f9
# ✅ Saved: The Running Man - IMDb: None, RT: None%
# 🔍 Fetching ratings for: Little Shop of Horrors...
# Error fetching OMDb ratings for Little Shop of Horrors: 401 Client Error: Unauthorized for url: https://www.omdbapi.com/?t=Little%20Shop%20of%20Horrors&apikey=4ab406f9
# ✅ Saved: Little Shop of Horrors - IMDb: None, RT: None%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 28
#      24     movies_ratings.to_csv(SAVE_FILE, index=False)
#      26     print(f"✅ Saved: {row['title']} - IMDb: {imdb}, RT: {rt}%")
# ---> 28     time.sleep(1)  # Avoid hitting rate limits
#      30 print("🎉 Done! All available ratings saved.")
#
# KeyboardInterrupt:

# %%
movies_ratings = pd.read_csv(SAVE_FILE)

# %%
ps = PorterStemmer()
def stem(text):
    return " ".join([ps.stem(word) for word in text.split()])
    
movies_ratings['tags'] = movies_ratings['tags'].apply(stem)

# %%
cv = CountVectorizer(max_features=5000, stop_words='english')
vectors = cv.fit_transform(movies_ratings['tags']).toarray()
similarity = cosine_similarity(vectors)

# %%
def get_top_recommendations(index):
    distances = similarity[index]
    movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:26]

    combined_scores = {}
    w_similarity = 0.9
    w_popularity = 0.1

    for i in movies_list:
        idx = i[0]
        sim_score = i[1]
        pop_score = movies_ratings.iloc[idx]['popularity_log_norm']

        combined_score = (w_similarity * sim_score) + (w_popularity * pop_score)
        combined_scores[idx] = combined_score

    sorted_combined_scores = sorted(combined_scores.items(), key=lambda x: x[1], reverse=True)
    top_10_indexes = [i[0] for i in sorted_combined_scores[:10]]

    return top_10_indexes

# %%
def handle_missing_values(x):
    if isinstance(x, (int, float)):  # If the value is numeric
        return 0 if np.isnan(x) else x  # Replace NaN with 0
    elif pd.isna(x) or x == '' or x is None:  # If the value is empty (NaN, None, empty string)
        return 0  # Replace empty or None with 0
    else:
        return x  # If the value is valid, leave it unchanged

# %%
movies_ratings['top_recommendations'] = [get_top_recommendations(i) for i in range(len(movies_ratings))]

# %%
movies_ratings['imdb_score'] = movies_ratings['imdb_score'].apply(handle_missing_values)
movies_ratings['rt_score'] = movies_ratings['rt_score'].apply(handle_missing_values)
movies_ratings[['movie_id', 'tags','title', 'overview', 'cast', 'crew', 'popularity_log_norm', 'year', 'imdb_score', 'rt_score', 'top_recommendations']].to_csv('processed_movies.csv', index=False)
